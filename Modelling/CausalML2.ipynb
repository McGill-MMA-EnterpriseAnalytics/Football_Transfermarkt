# %%
pip install "causalml[tf] @ git+https://github.com/uber/causalml"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting causalml[tf]@ git+https://github.com/uber/causalml
#   Cloning https://github.com/uber/causalml to /tmp/pip-install-i983vi35/causalml_7630db1ebff9467b94a707264f36a9d4
#   Running command git clone --filter=blob:none --quiet https://github.com/uber/causalml /tmp/pip-install-i983vi35/causalml_7630db1ebff9467b94a707264f36a9d4
#   Resolved https://github.com/uber/causalml to commit 3931ccf69dedb7f97c5be3c1b2d3e2fd7bc8b305
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: xgboost in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (1.7.5)
# Requirement already satisfied: Cython>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (0.29.34)
# Collecting pyro-ppl
#   Downloading pyro_ppl-1.8.4-py3-none-any.whl (730 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.7/730.7 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (0.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (23.1)
# Collecting pygam
#   Downloading pygam-0.9.0-py3-none-any.whl (522 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.2/522.2 kB 37.6 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (0.13.5)
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (2.0.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (4.65.0)
# Requirement already satisfied: pandas>=0.24.1 in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (1.5.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (67.7.2)
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 kB 43.3 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (3.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (1.22.4)
# Collecting forestci==0.6
#   Downloading forestci-0.6-py3-none-any.whl (12 kB)
# Collecting pathos==0.2.9
#   Downloading pathos-0.2.9-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (1.10.1)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (2.0.2)
# Requirement already satisfied: pip>=10.0 in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (23.0.1)
# Collecting scikit-learn<=1.0.2
#   Using cached scikit_learn-1.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.4 MB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (0.20.1)
# Requirement already satisfied: tensorflow>=2.4.0 in /usr/local/lib/python3.9/dist-packages (from causalml[tf]@ git+https://github.com/uber/causalml) (2.12.0)
# Collecting pox>=0.3.1
#   Downloading pox-0.3.2-py3-none-any.whl (29 kB)
# Collecting ppft>=1.7.6.5
#   Downloading ppft-1.7.6.6-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.5 MB/s eta 0:00:00
# Collecting multiprocess>=0.70.13
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.1->causalml[tf]@ git+https://github.com/uber/causalml) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.1->causalml[tf]@ git+https://github.com/uber/causalml) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<=1.0.2->causalml[tf]@ git+https://github.com/uber/causalml) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<=1.0.2->causalml[tf]@ git+https://github.com/uber/causalml) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.9.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.5.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (16.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (3.20.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.2.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2.12.2)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.53.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.4.8)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (4.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.32.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2.12.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (3.8.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2.12.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm->causalml[tf]@ git+https://github.com/uber/causalml) (0.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->causalml[tf]@ git+https://github.com/uber/causalml) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->causalml[tf]@ git+https://github.com/uber/causalml) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->causalml[tf]@ git+https://github.com/uber/causalml) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->causalml[tf]@ git+https://github.com/uber/causalml) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->causalml[tf]@ git+https://github.com/uber/causalml) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->causalml[tf]@ git+https://github.com/uber/causalml) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->causalml[tf]@ git+https://github.com/uber/causalml) (8.4.0)
# Collecting pygam
#   Downloading pygam-0.8.1-py3-none-any.whl (522 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.2/522.2 kB 45.5 MB/s eta 0:00:00
#   Downloading pygam-0.8.0-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.9/dist-packages (from pygam->causalml[tf]@ git+https://github.com/uber/causalml) (4.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from pygam->causalml[tf]@ git+https://github.com/uber/causalml) (0.18.3)
# Collecting pyro-api>=0.1.1
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch->causalml[tf]@ git+https://github.com/uber/causalml) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch->causalml[tf]@ git+https://github.com/uber/causalml) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch->causalml[tf]@ git+https://github.com/uber/causalml) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch->causalml[tf]@ git+https://github.com/uber/causalml) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch->causalml[tf]@ git+https://github.com/uber/causalml) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->causalml[tf]@ git+https://github.com/uber/causalml) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->causalml[tf]@ git+https://github.com/uber/causalml) (3.25.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from shap->causalml[tf]@ git+https://github.com/uber/causalml) (2.2.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from shap->causalml[tf]@ git+https://github.com/uber/causalml) (0.56.4)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->causalml[tf]@ git+https://github.com/uber/causalml) (3.15.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2.17.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2.2.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch->causalml[tf]@ git+https://github.com/uber/causalml) (2.1.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->shap->causalml[tf]@ git+https://github.com/uber/causalml) (0.39.1)
# Requirement already satisfied: python-utils>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from progressbar2->pygam->causalml[tf]@ git+https://github.com/uber/causalml) (3.5.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch->causalml[tf]@ git+https://github.com/uber/causalml) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (6.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (1.26.15)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.4.0->causalml[tf]@ git+https://github.com/uber/causalml) (3.2.2)
# Building wheels for collected packages: causalml
#   Building wheel for causalml (pyproject.toml) ... done
#   Created wheel for causalml: filename=causalml-0.13.0-cp39-cp39-linux_x86_64.whl size=1949109 sha256=d43b041f58ac3926401a45b2fc02d9b3d32a464b4925a907ae80c4717be1a76f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mv4bbqf7/wheels/9f/95/cc/00a52633613fec4ecaf9d9827ea143a5ae3889e801ce02479d
# Successfully built causalml
# Installing collected packages: pyro-api, slicer, ppft, pox, dill, scikit-learn, pygam, multiprocess, shap, pathos, forestci, pyro-ppl, causalml
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed causalml-0.13.0 dill-0.3.6 forestci-0.6 multiprocess-0.70.14 pathos-0.2.9 pox-0.3.2 ppft-1.7.6.6 pygam-0.8.0 pyro-api-0.1.2 pyro-ppl-1.8.4 scikit-learn-1.0.2 shap-0.41.0 slicer-0.0.7

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error as mse
from scipy.stats import entropy
import warnings

from causalml.inference.meta import LRSRegressor
from causalml.inference.meta import XGBTRegressor, MLPTRegressor
from causalml.inference.meta import BaseXRegressor, BaseRRegressor, BaseSRegressor, BaseTRegressor
from causalml.inference.tf import DragonNet
from causalml.match import NearestNeighborMatch, MatchOptimizer, create_table_one
from causalml.propensity import ElasticNetPropensityModel
from causalml.metrics import *
from causalml.dataset.regression import *


import os, sys

# %matplotlib inline

warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')
sns.set_palette('Paired')
plt.rcParams['figure.figsize'] = (12,8)

# %%
data=pd.read_csv('CausalML Data.csv')

# %%
data.drop(columns=['Unnamed: 0','foot','year_of_birth','player_id','max_market_value_in_eur'],inplace=True)

# %%
data.isna().sum()
# Out:
# year                              0
# avg_game_dur                      0
# avg_games_played                  0
# avg_yellow_cards                  0
# avg_red_cards                     0
# avg_goals                         0
# avg_assists                       0
# avg_minutes_played                0
# games_played_away                 0
# games_played_home                 0
# away_win_percentage               0
# home_win_percentage               0
# win_perc                          0
# games_player_domestic_cup         0
# games_played_domestic_league      0
# games_player_international_cup    0
# games_played_other                0
# player_avg_game_attendance        0
# mean_market_value_in_eur          0
# height_in_cm                      0
# age                               0
# contribution_per_game             0
# continent_embed_0                 0
# continent_embed_1                 0
# continent_embed_2                 0
# position_embed_0                  0
# position_embed_1                  0
# sub_position_embed_0              0
# sub_position_embed_1              0
# sub_position_embed_2              0
# sub_position_embed_3              0
# sub_position_embed_4              0
# sub_position_embed_5              0
# Both                              0
# Right                             0
# dtype: int64

# %%
s_ate_list=[]
t_ate_list=[]

y=np.array(data['mean_market_value_in_eur'])
treatment=np.array(data['Both'])
X=data.drop(columns=['mean_market_value_in_eur','Both'])

s_learner = BaseSRegressor(XGBRegressor())
s_ate = s_learner.estimate_ate(X, treatment, y)[0]
s_ite = s_learner.fit_predict(X, treatment, y)
s_ate_list.append(s_ate)

t_learner = BaseTRegressor(XGBRegressor())
t_ate = t_learner.estimate_ate(X, treatment, y)[0][0]
t_ite = t_learner.fit_predict(X, treatment, y)
t_ate_list.append(t_ate)

# %%
# T Learner
learner_t = BaseTRegressor(XGBRegressor())
cate_t = learner_t.fit_predict(X=X, treatment=treatment, y=y)

# %%
slearner = BaseSRegressor(XGBRegressor(), control_name=1)
slearner.estimate_ate(X, treatment, y)
# Out:
# array([-89204.87637035])

# %%
alpha=0.2
bins=30
plt.figure(figsize=(12,8))
plt.hist(cate_t, alpha=alpha, bins=bins, label='T Learner')
#plt.hist(cate_x, alpha=alpha, bins=bins, label='X Learner')
#plt.hist(cate_x_no_p, alpha=alpha, bins=bins, label='X Learner (no propensity score)')
#plt.hist(cate_r, alpha=alpha, bins=bins, label='R Learner')
#plt.hist(cate_r_no_p, alpha=alpha, bins=bins, label='R Learner (no propensity score)')
#plt.vlines(cate_s[0], 0, plt.axes().get_ylim()[1], label='S Learner',
#           linestyles='dotted', colors='green', linewidth=2)
plt.title('Distribution of CATE Predictions by Meta Learner')
plt.xlabel('Individual Treatment Effect (ITE/CATE)')
plt.ylabel('# of Samples')
_=plt.legend()

# %%
slearner = BaseSRegressor(XGBRegressor(), control_name=0)
slearner.estimate_ate(X, treatment, y)
# Out:
# array([89204.87637035])

# %%
slearner_tau = slearner.fit_predict(X, treatment, y)

# %%
slearner.plot_importance(X=X, 
                         tau=slearner_tau, 
                         normalize=True, 
                         method='auto', 
                         features=X.columns)

# %%
shap_slearner = slearner.get_shap_values(X=X, tau=slearner_tau)

# %%
slearner.plot_shap_values(X=X, tau=slearner_tau, features=X.columns)

# %%
slearner.plot_shap_dependence(treatment_group=1,
                              feature_idx='games_player_international_cup',
                              X=X,
                              tau=slearner_tau,
                              interaction_idx='auto',
                              shap_dict=shap_slearner,
                              features=X.columns)

# %% [markdown]
# T Learner

# %%
tlearner = BaseTRegressor(XGBRegressor(), control_name=0)
tlearner.estimate_ate(X, treatment, y)
# Out:
# (array([153288.5297792]), array([103713.28607896]), array([202863.77347944]))

# %%
tlearner_tau = tlearner.fit_predict(X, treatment, y)

# %%
tlearner.plot_importance(X=X, 
                         tau=tlearner_tau, 
                         normalize=True, 
                         method='auto', 
                         features=X.columns)

# %%
# Plot shap values without specifying shap_dict
tlearner.plot_shap_values(X=X, tau=tlearner_tau, features=X.columns)

# %%
shap_tlearner = tlearner.get_shap_values(X=X, tau=tlearner_tau)

# %%
# interaction_idx set to 'auto' (searches for feature with greatest approximate interaction)
# specify feature names
tlearner.plot_shap_dependence(treatment_group=1,
                              feature_idx='player_avg_game_attendance',
                              X=X,
                              tau=tlearner_tau,
                              interaction_idx='contribution_per_game',
                              shap_dict=shap_tlearner,
                              features=X.columns)
